# %% [markdown]
# <a href="https://colab.research.google.com/github/Atimangojackline/Atimangojackline/blob/main/BASIC_OF_PYTHONipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %%
print(123)
# Out:
# 123

# %%
x=10
print(x)
# Out:
# 10

# %%
x='Hello World'
print(x)
# Out:
# Hello World

# %%
x=10.5
print(x)
# Out:
# 10.5

# %%
x=5
y=10
print(x+y)
# Out:
# 15

# %%
x="Hello"
y="World"
print(x+y)
# Out:
# HelloWorld

# %%
x="hello" #This is a comment
print(x)
# Out:
# hello

# %%
x="ABC"
print(type(x))
# Out:
# <class 'str'>

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
x='10'
print(type(x))
# Out:
# <class 'str'>

# %%
x=10
y=20
z=x+y
print(type(z))
# Out:
# <class 'int'>

# %%
a='10'
b='20'
c=a+b
print(type(c))
# Out:
# <class 'str'>

# %%
a=3.564
print("a= ", a)
# Out:
# a=  3.564

# %%
x=10
y=5
print("x is {} and y is {}" .format(x,y))
# Out:
# x is 10 and y is 5

# %%
num=input('enter a number: ')
print('you entered: ', num)
# Out:
# enter a number: 90
# you entered:  90

# %%
name=input('enter your name?')
print('nice to meet u '+ name +"!")
# Out:
# enter your name?jafrvfrv
# nice to meet u jafrvfrv!

# %%
num=input('A = ')
print('Type=', type(num))
# Out:
# A = 8
# Type= <class 'str'>

# %%
x=int(input("enter number 1: "))
y=int(input("enter number 2:"))
print("x+y=", x+y)
# Out:
# enter number 1: 6
# enter number 2:9
# x+y= 15

# %%
a,b,c,d ='name', 'age','place', 'class'
print(a,b,c,d)
# Out:
# name age place class

# %%
x=int(input())
y=int(input())
print(x>y)
print(type(x>y))
# Out:
# 9
# 8
# True
# <class 'bool'>

# %%
x=bytearray(5)
print(x)
print(type(x))
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')
# <class 'bytearray'>

# %%
x=bytearray(12345)

# %%
x
# Out:
# bytearray(b'\x
# ...

# %%
x=None
print(x)
print(type(x))
# Out:
# None
# <class 'NoneType'>

# %%
x=10.5
print(x)
print(type(x))
y=int(x)
print(y)
print(type(y))
# Out:
# 10.5
# <class 'float'>
# 10
# <class 'int'>

# %%
x='10'
print(x)
print(type(x))
y=int(x)
print(y)
print(type(y))
# Out:
# 10
# <class 'str'>
# 10
# <class 'int'>

# %%
x_y=10
y_x=20
x_y+y_x
# Out:
# 30

# %%
_x=10
_y=20
_x+_y
# Out:
# 30

# %%
ABC= 'Hello World'
abc='Hello World'
print(ABC)
print(abc)
# Out:
# Hello World
# Hello World

# %%
ABC1='Hello World'
1ABC='Hello World'
print(ABC1)
print(1ABC)
# Out:
#   File "<ipython-input-40-04ae0d98ab7d>", line 2
#     1ABC='Hello World'
#      ^
# SyntaxError: invalid syntax

# %%
1ABC='Hello World'
print(1ABC)
# Out:
#   File "<ipython-input-41-be4130874944>", line 1
#     1ABC='Hello World'
#      ^
# SyntaxError: invalid syntax

# %%
2_ABC='Hello World'
print(2_ABC)
# Out:
#   File "<ipython-input-42-8942881bb73a>", line 1
#     2_ABC='Hello World'
#      ^
# SyntaxError: invalid decimal literal

# %%
A_BCD= 'Hello World'
print(A_BCD)
# Out:
# Hello World

# %%
A BCD='Hello World'
printr(A BCD)
# Out:
#   File "<ipython-input-54-10cee7064e1a>", line 1
#     A BCD='Hello World'
#       ^
# SyntaxError: invalid syntax

# %%
x=10
print(x+ = 3)
print(x %= 3)

# %%
x=10

# %%
x += 3

# %%
x
# Out:
# 13

# %%
x %= 3

# %%
x
# Out:
# 1

# %%
X=10

# %%
X%2
# Out:
# 0

# %%
X
# Out:
# 10

# %%
X , Y = 10, 25
print(x != y)
# Out:
# True

# %%
print(x >= y)
# Out:
# False

# %%
x=2
y=10
print(x+y)
print(x-y)
print(x/y)
# Out:
# 12
# -8
# 0.2

# %%
print(11 % 5)
# Out:
# 1

# %%
print(11 // 5)
# Out:
# 2

# %%
x= 2**6

# %%
x
# Out:
# 64
